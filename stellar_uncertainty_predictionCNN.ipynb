# %%
# mount google drive to load files directly from there
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# if you want to import Python files, add the correct Google Drive directory to your Pythonpath
import sys
sys.path.append('/content/drive/My Drive/AdvDL/stellar-parameter-prediction')

# %%
# Download the data from huggingface (https://huggingface.co/datasets/simbaswe/galah4/tree/main)
# and upload it to your google drive. Then, specify this directory here
DATA_PATH = '/content/drive/My Drive/AdvDL/stellar-parameter-prediction/data'

# %%
# import the stuff you need. Pytorch is already installed on Google colab
import os
import time
import sys
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
from matplotlib import pyplot as plt
from torchsummary import summary
from CNNhelper import normalize, denormalize, train_model, get_normalized_data, evaluate_model

# %%
import torch
import torch.nn as nn

class TinyCNN(nn.Module):
    def __init__(self, nLabels):
        super(TinyCNN, self).__init__()

        self.model = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=5, padding=2),  # Input: (B, 1, L)
            nn.ReLU(),
            nn.BatchNorm1d(16),
            nn.AvgPool1d(2),                            # Output: (B, 16, L/2)

            nn.Conv1d(16, 32, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.BatchNorm1d(32),
            nn.AvgPool1d(2),                            # Output: (B, 32, L/4)

            nn.Conv1d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.AvgPool1d(2),                            # Output: (B, 64, L/8)

            nn.AdaptiveAvgPool1d(1),                    # Output: (B, 64, 1)
            nn.Flatten(),                               # Output: (B, 64)
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, nLabels*2)                      # Output: (B, nLabels*2) --- doubled number of output labels to predict both nominal value (mu) and uncertainty (log(sigma))
        )

    def forward(self, x):
        return self.model(x)

# %%
spectra = np.load(f"{DATA_PATH}/spectra.npy")
spectra_length = spectra.shape[1]
# labels: mass, age, l_bol, dist, t_eff, log_g, fe_h, SNR
labelNames = ["mass", "age", "l_bol", "dist", "t_eff", "log_g", "fe_h", "SNR"]
labels = np.load(f"{DATA_PATH}/labels.npy")
# We only use the three labels: t_eff, log_g, fe_h, SNR
labelNames = labelNames[-4:-1]
labels = labels[:, -4:-1]
print(f"spectra shape: {spectra.shape}")
print(f"labels shape: {labels.shape}")
# spectra length is 16384 and we are predicting 3 labels
# we have 8914 samples
# Out:
# spectra shape: (8914, 16384)
# labels shape: (8914, 3)

# %%
# plot a few spectra
"""%matplotlib inline
# plot a few spectra
for i in range(10):
  fig, ax = plt.subplots(1, 1, figsize=(10, 5))
  ax.plot(spectra[i], lw=1)
  ax.set_title(f"Star {i}")
  plt.tight_layout()"""
# Out:
# '%matplotlib inline\n# plot a few spectra\nfor i in range(10):\n  fig, ax = plt.subplots(1, 1, figsize=(10, 5))\n  ax.plot(spectra[i], lw=1)\n  ax.set_title(f"Star {i}")\n  plt.tight_layout()'

# %%
#Model implementation:

# Hyperparameters
learning_rate = 2e-4
batch_size = 32
num_epochs = 100
patience = 10 # Training loop with early stopping, if the validation loss does not improve for 'patience' epochs
train_fraction = 0.7 # Fraction of the data used for training
val_fraction = 0.15 # Fraction of the data used for validation

# %%
# Call the helper function to get normalized data
spectra, labels, spectra_length, n_labels, labelNames, ranges = get_normalized_data(DATA_PATH)

# %%
# Convert numpy arrays to PyTorch tensors
spectra_tensor = torch.tensor(spectra, dtype=torch.float32)
labels_tensor = torch.tensor(labels, dtype=torch.float32)

# %%
# Split the data into training, validation, and test sets
total_samples = len(spectra_tensor) #8914 samples
train_size = int(train_fraction * total_samples) #0.7 * 8914 = 6249
val_size = int(val_fraction * total_samples) #0.15 * 8914 = 1337
test_size = total_samples - train_size - val_size # 8914 - 6249 - 1337 = 1328
train_dataset, val_dataset, test_dataset = random_split(TensorDataset(spectra_tensor, labels_tensor), [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

# %%
# Detect and use Apple Silicon GPU (MPS) if available
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)
# Out:
# Using device: cuda
# TinyCNN(
#   (model): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU()
#     (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (4): Conv1d(16, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (8): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU()
#     (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (12): AdaptiveAvgPool1d(output_size=1)
#     (13): Flatten(start_dim=1, end_dim=-1)
#     (14): Linear(in_features=64, out_features=64, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=64, out_features=6, bias=True)
#   )
# )

# %%
# Create DataLoaders for batching and shuffling the data
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

## Model selection
model_choice = 'TinyCNN'
if model_choice == 'TinyCNN':
    model = TinyCNN(n_labels)
else:
    raise ValueError("Invalid model choice. Please select 'TinyCNN'.")
model = model.to(device)


# Print the model summary before moving it to the device
summary(model, input_size=(1, spectra_length))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 16384]              96
#               ReLU-2            [-1, 16, 16384]               0
#        BatchNorm1d-3            [-1, 16, 16384]              32
#          AvgPool1d-4             [-1, 16, 8192]               0
#             Conv1d-5             [-1, 32, 8192]           2,592
#               ReLU-6             [-1, 32, 8192]               0
#        BatchNorm1d-7             [-1, 32, 8192]              64
#          AvgPool1d-8             [-1, 32, 4096]               0
#             Conv1d-9             [-1, 64, 4096]           6,208
#              ReLU-10             [-1, 64, 4096]               0
#       BatchNorm1d-11             [-1, 64, 4096]             128
#         AvgPool1d-12             [-1, 64, 2048]               0
# AdaptiveAvgPool1d-13                [-1, 64, 1]               0
#           Flatten-14                   [-1, 64]               0
#            Linear-15                   [-1, 64]           4,160
#              ReLU-16                   [-1, 64]               0
#            Linear-17                    [-1, 6]             390
# ================================================================
# Total params: 13,670
# Trainable params: 13,670
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 21.00
# Params size (MB): 0.05
# Estimated Total Size (MB): 21.12
# ----------------------------------------------------------------

# %%
# Define the loss function and optimizer

def nll_loss(inputs, labels, model):
    """
    Computes the Gaussian Negative Log-Likelihood loss.

    The model outputs 6 values per sample: 3 means and 3 log standard deviations.
    """
    predictions = model(inputs)  # shape: (B, 6)
    n = predictions.shape[1] // 2  # n=3 --- 3 for μ, 3 for log σ

    mu = predictions[:, :n]
    log_sigma = predictions[:, n:]

    # Compute the NLL
    mse_term = ((labels - mu)**2) / torch.exp(2 * log_sigma)
    nll = log_sigma + 0.5 * mse_term #nll is a per-sample, per-label loss matrix, tensor shape (B, 3)

    return nll.mean()

# %%
# Train the model
loss_function = nll_loss
train_losses, val_losses, best_model = train_model(model, train_loader, val_loader, loss_function, learning_rate, num_epochs, patience, device)
# Out:
# Epoch [1/100], Step [190/195], Loss: -0.7028
# Epoch [1/100], Train Loss: -0.1515, Val Loss: -0.6389, Time: 2.95 seconds
# Epoch [2/100], Step [190/195], Loss: -0.7233
# Epoch [2/100], Train Loss: -0.7728, Val Loss: -0.9366, Time: 2.32 seconds
# Epoch [3/100], Step [190/195], Loss: -0.7071
# Epoch [3/100], Train Loss: -0.8979, Val Loss: -1.0147, Time: 2.36 seconds
# Epoch [4/100], Step [190/195], Loss: -0.8495
# Epoch [4/100], Train Loss: -0.9784, Val Loss: -1.0537, Time: 2.32 seconds
# Epoch [5/100], Step [190/195], Loss: -1.0610
# Epoch [5/100], Train Loss: -1.0271, Val Loss: -1.0412, Time: 2.37 seconds
# Epoch [6/100], Step [190/195], Loss: -1.0402
# Epoch [6/100], Train Loss: -1.0789, Val Loss: -1.1119, Time: 2.36 seconds
# Epoch [7/100], Step [190/195], Loss: -1.3306
# Epoch [7/100], Train Loss: -1.1318, Val Loss: -1.2034, Time: 2.36 seconds
# Epoch [8/100], Step [190/195], Loss: -1.1523
# Epoch [8/100], Train Loss: -1.1778, Val Loss: -1.2012, Time: 2.35 seconds
# Epoch [9/100], Step [190/195], Loss: -1.3457
# Epoch [9/100], Train Loss: -1.2223, Val Loss: -1.1358, Time: 2.38 seconds
# Epoch [10/100], Step [190/195], Loss: -1.2692
# Epoch [10/100], Train Loss: -1.2715, Val Loss: -1.3230, Time: 2.37 seconds
# Epoch [11/100], Step [190/195], Loss: -1.4885
# Epoch [11/100], Train Loss: -1.3158, Val Loss: -1.3264, Time: 2.38 seconds
# Epoch [12/100], Step [190/195], Loss: -1.4435
# Epoch [12/100], Train Loss: -1.3543, Val Loss: -1.3997, Time: 2.41 seconds
# Epoch [13/100], Step [190/195], Loss: -1.5000
# Epoch [13/100], Train Loss: -1.3927, Val Loss: -1.4554, Time: 2.38 seconds
# Epoch [14/100], Step [190/195], Loss: -1.5135
# Epoch [14/100], Train Loss: -1.4416, Val Loss: -1.3243, Time: 2.39 seconds
# Epoch [15/100], Step [190/195], Loss: -1.5861
# Epoch [15/100], Train Loss: -1.4565, Val Loss: -1.3944, Time: 2.39 seconds
# Epoch [16/100], Step [190/195], Loss: -1.5242
# Epoch [16/100], Train Loss: -1.4758, Val Loss: -1.4811, Time: 2.39 seconds
# Epoch [17/100], Step [190/195], Loss: -1.4393
# Epoch [17/100], Train Loss: -1.5040, Val Loss: -1.1872, Time: 2.38 seconds
# Epoch [18/100], Step [190/195], Loss: -1.4805
# Epoch [18/100], Train Loss: -1.4418, Val Loss: 36.4392, Time: 2.38 seconds
# Epoch [19/100], Step [190/195], Loss: -1.4472
# Epoch [19/100], Train Loss: -1.3458, Val Loss: -1.3280, Time: 2.39 seconds
# Epoch [20/100], Step [190/195], Loss: -1.7500
# Epoch [20/100], Train Loss: -1.4794, Val Loss: -1.4985, Time: 2.39 seconds
# Epoch [21/100], Step [190/195], Loss: -1.7118
# Epoch [21/100], Train Loss: -1.5101, Val Loss: -1.5908, Time: 2.40 seconds
# Epoch [22/100], Step [190/195], Loss: -1.5876
# Epoch [22/100], Train Loss: -1.5466, Val Loss: -1.5457, Time: 2.38 seconds
# Epoch [23/100], Step [190/195], Loss: -1.6117
# Epoch [23/100], Train Loss: -1.5588, Val Loss: -1.6131, Time: 2.40 seconds
# Epoch [24/100], Step [190/195], Loss: -1.7220
# Epoch [24/100], Train Loss: -1.5668, Val Loss: -1.6837, Time: 2.39 seconds
# Epoch [25/100], Step [190/195], Loss: -1.5601
# Epoch [25/100], Train Loss: -1.5906, Val Loss: -1.0429, Time: 2.40 seconds
# Epoch [26/100], Step [190/195], Loss: -1.7454
# Epoch [26/100], Train Loss: -1.6036, Val Loss: -1.6119, Time: 2.38 seconds
# Epoch [27/100], Step [190/195], Loss: -1.4958
# Epoch [27/100], Train Loss: -1.6247, Val Loss: -1.5043, Time: 2.40 seconds
# Epoch [28/100], Step [190/195], Loss: -1.4600
# Epoch [28/100], Train Loss: -1.6512, Val Loss: -1.3579, Time: 2.39 seconds
# Epoch [29/100], Step [190/195], Loss: -1.1316
# Epoch [29/100], Train Loss: -1.6527, Val Loss: -1.5104, Time: 2.40 seconds
# Epoch [30/100], Step [190/195], Loss: -1.7034
# Epoch [30/100], Train Loss: -1.6698, Val Loss: -1.7645, Time: 2.38 seconds
# Epoch [31/100], Step [190/195], Loss: -1.6141
# Epoch [31/100], Train Loss: -1.6864, Val Loss: -1.5865, Time: 2.41 seconds
# Epoch [32/100], Step [190/195], Loss: -1.6496
# Epoch [32/100], Train Loss: -1.6887, Val Loss: -1.7916, Time: 2.41 seconds
# Epoch [33/100], Step [190/195], Loss: -1.7788
# Epoch [33/100], Train Loss: -1.7265, Val Loss: -1.7521, Time: 2.40 seconds
# Epoch [34/100], Step [190/195], Loss: -1.8577
# Epoch [34/100], Train Loss: -1.7170, Val Loss: -1.5707, Time: 2.40 seconds
# Epoch [35/100], Step [190/195], Loss: -1.3096
# Epoch [35/100], Train Loss: -1.7404, Val Loss: -1.7456, Time: 2.40 seconds
# Epoch [36/100], Step [190/195], Loss: -1.6512
# Epoch [36/100], Train Loss: -1.7700, Val Loss: -1.8866, Time: 2.41 seconds
# Epoch [37/100], Step [190/195], Loss: -1.5182
# Epoch [37/100], Train Loss: -1.7824, Val Loss: -1.8996, Time: 2.41 seconds
# Epoch [38/100], Step [190/195], Loss: -1.7997
# Epoch [38/100], Train Loss: -1.7980, Val Loss: -1.6702, Time: 2.41 seconds
# Epoch [39/100], Step [190/195], Loss: -1.9267
# Epoch [39/100], Train Loss: -1.8249, Val Loss: -1.1541, Time: 2.41 seconds
# Epoch [40/100], Step [190/195], Loss: -1.6080
# Epoch [40/100], Train Loss: -1.7988, Val Loss: -1.6487, Time: 2.40 seconds
# Epoch [41/100], Step [190/195], Loss: -1.7063
# Epoch [41/100], Train Loss: -1.8342, Val Loss: -1.7222, Time: 2.40 seconds
# Epoch [42/100], Step [190/195], Loss: -1.7902
# Epoch [42/100], Train Loss: -1.8521, Val Loss: -1.5719, Time: 2.41 seconds
# Epoch [43/100], Step [190/195], Loss: -1.8666
# Epoch [43/100], Train Loss: -1.8571, Val Loss: -1.9847, Time: 2.41 seconds
# Epoch [44/100], Step [190/195], Loss: -1.8163
# Epoch [44/100], Train Loss: -1.8630, Val Loss: -1.7008, Time: 2.40 seconds
# Epoch [45/100], Step [190/195], Loss: -1.8028
# Epoch [45/100], Train Loss: -1.8801, Val Loss: -1.6144, Time: 2.40 seconds
# Epoch [46/100], Step [190/195], Loss: -1.8509
# Epoch [46/100], Train Loss: -1.8723, Val Loss: -1.8018, Time: 2.40 seconds
# Epoch [47/100], Step [190/195], Loss: -1.4676
# Epoch [47/100], Train Loss: -1.8996, Val Loss: -1.1072, Time: 2.42 seconds
# Epoch [48/100], Step [190/195], Loss: -2.0307
# Epoch [48/100], Train Loss: -1.9073, Val Loss: -1.9814, Time: 2.38 seconds
# Epoch [49/100], Step [190/195], Loss: -1.9179
# Epoch [49/100], Train Loss: -1.9028, Val Loss: 2.3128, Time: 2.42 seconds
# Epoch [50/100], Step [190/195], Loss: -1.8231
# Epoch [50/100], Train Loss: -1.8827, Val Loss: -1.5008, Time: 2.42 seconds
# Epoch [51/100], Step [190/195], Loss: -1.9662
# Epoch [51/100], Train Loss: -1.7555, Val Loss: -1.7436, Time: 2.39 seconds
# Epoch [52/100], Step [190/195], Loss: -1.9504
# Epoch [52/100], Train Loss: -1.8613, Val Loss: -1.9407, Time: 2.41 seconds
# Epoch [53/100], Step [190/195], Loss: -1.9969
# Epoch [53/100], Train Loss: -1.8961, Val Loss: -1.9396, Time: 2.39 seconds
# Early stopping triggered.

# %%
model.load_state_dict(best_model) #Load the best model
# save the best model to the "models" directory
if not os.path.exists('models'):
    os.makedirs('models')
torch.save(best_model, f'models/{model_choice}_best.pth')
model.to(device)
# Out:
# TinyCNN(
#   (model): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU()
#     (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (4): Conv1d(16, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (8): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU()
#     (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (12): AdaptiveAvgPool1d(output_size=1)
#     (13): Flatten(start_dim=1, end_dim=-1)
#     (14): Linear(in_features=64, out_features=64, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=64, out_features=6, bias=True)
#   )
# )

# %%
def evaluate_model_with_uncertainty(model, test_loader, device):
    """
    Evaluate model predictions and uncertainty calibration via pull distributions.
    """
    print("Evaluating model with uncertainty on the test dataset...")
    model.eval()

    all_mu = []
    all_log_sigma = []
    all_labels = []
    all_pulls = []

    with torch.no_grad():
        for batch_spectra, batch_labels in test_loader:
            batch_spectra = batch_spectra.to(device).unsqueeze(1)
            batch_labels = batch_labels.to(device)

            outputs = model(batch_spectra)
            mu = outputs[:, :3]
            log_sigma = outputs[:, 3:]
            sigma = torch.exp(log_sigma)

            pulls = (batch_labels - mu) / sigma

            all_mu.append(mu.cpu())
            all_log_sigma.append(log_sigma.cpu())
            all_labels.append(batch_labels.cpu())
            all_pulls.append(pulls.cpu())

    mu = torch.cat(all_mu).numpy()
    log_sigma = torch.cat(all_log_sigma).numpy()
    sigma = np.exp(log_sigma)
    labels = torch.cat(all_labels).numpy()
    pulls = torch.cat(all_pulls).numpy()

    return mu, sigma, labels, pulls

# %%
mu, sigma, labels, pulls = evaluate_model_with_uncertainty(model, test_loader, device)
# Out:
# Evaluating model with uncertainty on the test dataset...

# %%
import scipy.stats as stats

for j in range(3):
    plt.figure(figsize=(6, 4))
    plt.hist(pulls[:, j], bins=50, density=True, alpha=0.7, label='Pulls')
    x = np.linspace(-5, 5, 200)
    plt.plot(x, stats.norm.pdf(x), 'k--', label='Standard Normal')
    plt.axvline(pulls[:, j].mean(), color='r', linestyle=':', label=f'Mean: {pulls[:, j].mean():.2f}')
    plt.axvline(pulls[:, j].mean() + pulls[:, j].std(), color='g', linestyle='--', label=f'Std: {pulls[:, j].std():.2f}')
    plt.axvline(pulls[:, j].mean() - pulls[:, j].std(), color='g', linestyle='--')
    plt.title(f"Pull distribution for {labelNames[j]}")
    plt.xlabel("Pull value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Negative Log-Likelihood Loss')
plt.title('Training and Validation Loss over Epochs')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
