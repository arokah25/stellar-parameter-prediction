# %%
# mount google drive to load files directly from there
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# if you want to import Python files, add the correct Google Drive directory to your Pythonpath
import sys
sys.path.append('/content/drive/My Drive/AdvDL/stellar-parameter-prediction')

# %%
# Download the data from huggingface (https://huggingface.co/datasets/simbaswe/galah4/tree/main)
# and upload it to your google drive. Then, specify this directory here
DATA_PATH = '/content/drive/My Drive/AdvDL/stellar-parameter-prediction/data'

# %%
# import the stuff you need. Pytorch is already installed on Google colab
import os
import time
import sys
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, random_split
import numpy as np
from matplotlib import pyplot as plt
from torchsummary import summary
from CNNhelper import normalize, denormalize, train_model, get_normalized_data, evaluate_model

# %%
import torch
import torch.nn as nn

class TinyCNN(nn.Module):
    def __init__(self, nLabels):
        super(TinyCNN, self).__init__()

        self.model = nn.Sequential(
            nn.Conv1d(1, 16, kernel_size=5, padding=2),  # Input: (B, 1, L)
            nn.ReLU(),
            nn.BatchNorm1d(16),
            nn.AvgPool1d(2),                            # Output: (B, 16, L/2)

            nn.Conv1d(16, 32, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.BatchNorm1d(32),
            nn.AvgPool1d(2),                            # Output: (B, 32, L/4)

            nn.Conv1d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.AvgPool1d(2),                            # Output: (B, 64, L/8)

            nn.AdaptiveAvgPool1d(1),                    # Output: (B, 64, 1)
            nn.Flatten(),                               # Output: (B, 64)
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, nLabels)                      # Output: (B, nLabels)
        )

    def forward(self, x):
        return self.model(x)

# %%
spectra = np.load(f"{DATA_PATH}/spectra.npy")
spectra_length = spectra.shape[1]
# labels: mass, age, l_bol, dist, t_eff, log_g, fe_h, SNR
labelNames = ["mass", "age", "l_bol", "dist", "t_eff", "log_g", "fe_h", "SNR"]
labels = np.load(f"{DATA_PATH}/labels.npy")
# We only use the three labels: t_eff, log_g, fe_h, SNR
labelNames = labelNames[-4:-1]
labels = labels[:, -4:-1]
print(f"spectra shape: {spectra.shape}")
print(f"labels shape: {labels.shape}")
# spectra length is 16384 and we are predicting 3 labels
# we have 8914 samples
# Out:
# spectra shape: (8914, 16384)
# labels shape: (8914, 3)

# %%
# plot a few spectra
"""%matplotlib inline
# plot a few spectra
for i in range(10):
  fig, ax = plt.subplots(1, 1, figsize=(10, 5))
  ax.plot(spectra[i], lw=1)
  ax.set_title(f"Star {i}")
  plt.tight_layout()"""
# Out:
# '%matplotlib inline\n# plot a few spectra\nfor i in range(10):\n  fig, ax = plt.subplots(1, 1, figsize=(10, 5))\n  ax.plot(spectra[i], lw=1)\n  ax.set_title(f"Star {i}")\n  plt.tight_layout()'

# %%
#Model implementation:

# Hyperparameters
learning_rate = 2e-4
batch_size = 32
num_epochs = 100
patience = 10 # Training loop with early stopping, if the validation loss does not improve for 'patience' epochs
train_fraction = 0.7 # Fraction of the data used for training
val_fraction = 0.15 # Fraction of the data used for validation

# %%
# Call the helper function to get normalized data
spectra, labels, spectra_length, n_labels, labelNames, ranges = get_normalized_data(DATA_PATH)

# %%
# Convert numpy arrays to PyTorch tensors
spectra_tensor = torch.tensor(spectra, dtype=torch.float32)
labels_tensor = torch.tensor(labels, dtype=torch.float32)

# %%
# Split the data into training, validation, and test sets
total_samples = len(spectra_tensor) #8914 samples
train_size = int(train_fraction * total_samples) #0.7 * 8914 = 6249
val_size = int(val_fraction * total_samples) #0.15 * 8914 = 1337
test_size = total_samples - train_size - val_size # 8914 - 6249 - 1337 = 1328
train_dataset, val_dataset, test_dataset = random_split(TensorDataset(spectra_tensor, labels_tensor), [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42))

# %%
# Detect and use Apple Silicon GPU (MPS) if available
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
model.to(device)
# Out:
# Using device: cuda
# TinyCNN(
#   (model): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU()
#     (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (4): Conv1d(16, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (8): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU()
#     (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (12): AdaptiveAvgPool1d(output_size=1)
#     (13): Flatten(start_dim=1, end_dim=-1)
#     (14): Linear(in_features=64, out_features=64, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
# Create DataLoaders for batching and shuffling the data
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

## Model selection
model_choice = 'TinyCNN'
if model_choice == 'TinyCNN':
    model = TinyCNN(n_labels)
else:
    raise ValueError("Invalid model choice. Please select 'TinyCNN'.")
model = model.to(device)


# Print the model summary before moving it to the device
summary(model, input_size=(1, spectra_length))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1            [-1, 16, 16384]              96
#               ReLU-2            [-1, 16, 16384]               0
#        BatchNorm1d-3            [-1, 16, 16384]              32
#          AvgPool1d-4             [-1, 16, 8192]               0
#             Conv1d-5             [-1, 32, 8192]           2,592
#               ReLU-6             [-1, 32, 8192]               0
#        BatchNorm1d-7             [-1, 32, 8192]              64
#          AvgPool1d-8             [-1, 32, 4096]               0
#             Conv1d-9             [-1, 64, 4096]           6,208
#              ReLU-10             [-1, 64, 4096]               0
#       BatchNorm1d-11             [-1, 64, 4096]             128
#         AvgPool1d-12             [-1, 64, 2048]               0
# AdaptiveAvgPool1d-13                [-1, 64, 1]               0
#           Flatten-14                   [-1, 64]               0
#            Linear-15                   [-1, 64]           4,160
#              ReLU-16                   [-1, 64]               0
#            Linear-17                    [-1, 3]             195
# ================================================================
# Total params: 13,475
# Trainable params: 13,475
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 21.00
# Params size (MB): 0.05
# Estimated Total Size (MB): 21.12
# ----------------------------------------------------------------

# %%
# Define the loss function and optimizer
mse_loss = nn.MSELoss()
def loss_function(inputs, labels, model):
    """
    Computes the loss between the model predictions and the true labels using mean squared error (MSE).

    Parameters
    ----------
    inputs : array-like
        The input data to the model.
    labels : array-like
        The true labels corresponding to the input data.
    model : object
        The model used to make predictions.

    Returns
    -------
    float
        The computed mean squared error loss.
    """
    predictions = model(inputs)
    loss_result = mse_loss(predictions, labels)
    return loss_result

# %%
# Train the model
train_losses, val_losses, best_model = train_model(model, train_loader, val_loader, loss_function, learning_rate, num_epochs, patience, device)
# Out:
# Epoch [1/100], Step [190/195], Loss: 0.1066
# Epoch [1/100], Train Loss: 0.2249, Val Loss: 0.0811, Time: 2.39 seconds
# Epoch [2/100], Step [190/195], Loss: 0.0544
# Epoch [2/100], Train Loss: 0.0853, Val Loss: 0.0674, Time: 2.39 seconds
# Epoch [3/100], Step [190/195], Loss: 0.0866
# Epoch [3/100], Train Loss: 0.0695, Val Loss: 0.0614, Time: 2.39 seconds
# Epoch [4/100], Step [190/195], Loss: 0.0552
# Epoch [4/100], Train Loss: 0.0627, Val Loss: 0.0530, Time: 2.40 seconds
# Epoch [5/100], Step [190/195], Loss: 0.0455
# Epoch [5/100], Train Loss: 0.0543, Val Loss: 0.0490, Time: 2.40 seconds
# Epoch [6/100], Step [190/195], Loss: 0.0486
# Epoch [6/100], Train Loss: 0.0487, Val Loss: 0.0480, Time: 2.40 seconds
# Epoch [7/100], Step [190/195], Loss: 0.0650
# Epoch [7/100], Train Loss: 0.0441, Val Loss: 0.0496, Time: 2.39 seconds
# Epoch [8/100], Step [190/195], Loss: 0.0345
# Epoch [8/100], Train Loss: 0.0398, Val Loss: 0.0389, Time: 2.40 seconds
# Epoch [9/100], Step [190/195], Loss: 0.0928
# Epoch [9/100], Train Loss: 0.0367, Val Loss: 0.0366, Time: 2.41 seconds
# Epoch [10/100], Step [190/195], Loss: 0.0277
# Epoch [10/100], Train Loss: 0.0345, Val Loss: 0.0383, Time: 2.41 seconds
# Epoch [11/100], Step [190/195], Loss: 0.0206
# Epoch [11/100], Train Loss: 0.0313, Val Loss: 0.0333, Time: 2.42 seconds
# Epoch [12/100], Step [190/195], Loss: 0.0234
# Epoch [12/100], Train Loss: 0.0294, Val Loss: 0.0335, Time: 2.41 seconds
# Epoch [13/100], Step [190/195], Loss: 0.0275
# Epoch [13/100], Train Loss: 0.0269, Val Loss: 0.0244, Time: 2.42 seconds
# Epoch [14/100], Step [190/195], Loss: 0.0259
# Epoch [14/100], Train Loss: 0.0254, Val Loss: 0.0277, Time: 2.41 seconds
# Epoch [15/100], Step [190/195], Loss: 0.0160
# Epoch [15/100], Train Loss: 0.0238, Val Loss: 0.0340, Time: 2.41 seconds
# Epoch [16/100], Step [190/195], Loss: 0.0134
# Epoch [16/100], Train Loss: 0.0220, Val Loss: 0.0263, Time: 2.41 seconds
# Epoch [17/100], Step [190/195], Loss: 0.0406
# Epoch [17/100], Train Loss: 0.0204, Val Loss: 0.0295, Time: 2.40 seconds
# Epoch [18/100], Step [190/195], Loss: 0.0159
# Epoch [18/100], Train Loss: 0.0187, Val Loss: 0.0151, Time: 2.41 seconds
# Epoch [19/100], Step [190/195], Loss: 0.0151
# Epoch [19/100], Train Loss: 0.0182, Val Loss: 0.0228, Time: 2.40 seconds
# Epoch [20/100], Step [190/195], Loss: 0.0169
# Epoch [20/100], Train Loss: 0.0168, Val Loss: 0.0222, Time: 2.43 seconds
# Epoch [21/100], Step [190/195], Loss: 0.0090
# Epoch [21/100], Train Loss: 0.0157, Val Loss: 0.0133, Time: 2.42 seconds
# Epoch [22/100], Step [190/195], Loss: 0.0138
# Epoch [22/100], Train Loss: 0.0154, Val Loss: 0.0125, Time: 2.41 seconds
# Epoch [23/100], Step [190/195], Loss: 0.0202
# Epoch [23/100], Train Loss: 0.0148, Val Loss: 0.0418, Time: 2.42 seconds
# Epoch [24/100], Step [190/195], Loss: 0.0110
# Epoch [24/100], Train Loss: 0.0141, Val Loss: 0.0257, Time: 2.43 seconds
# Epoch [25/100], Step [190/195], Loss: 0.0133
# Epoch [25/100], Train Loss: 0.0138, Val Loss: 0.0155, Time: 2.43 seconds
# Epoch [26/100], Step [190/195], Loss: 0.0086
# Epoch [26/100], Train Loss: 0.0145, Val Loss: 0.0267, Time: 2.41 seconds
# Epoch [27/100], Step [190/195], Loss: 0.0140
# Epoch [27/100], Train Loss: 0.0141, Val Loss: 0.0154, Time: 2.42 seconds
# Epoch [28/100], Step [190/195], Loss: 0.0130
# Epoch [28/100], Train Loss: 0.0130, Val Loss: 0.0161, Time: 2.43 seconds
# Epoch [29/100], Step [190/195], Loss: 0.0105
# Epoch [29/100], Train Loss: 0.0124, Val Loss: 0.0107, Time: 2.42 seconds
# Epoch [30/100], Step [190/195], Loss: 0.0226
# Epoch [30/100], Train Loss: 0.0120, Val Loss: 0.0134, Time: 2.43 seconds
# Epoch [31/100], Step [190/195], Loss: 0.0097
# Epoch [31/100], Train Loss: 0.0119, Val Loss: 0.0090, Time: 2.42 seconds
# Epoch [32/100], Step [190/195], Loss: 0.0157
# Epoch [32/100], Train Loss: 0.0116, Val Loss: 0.0094, Time: 2.43 seconds
# Epoch [33/100], Step [190/195], Loss: 0.0133
# Epoch [33/100], Train Loss: 0.0120, Val Loss: 0.0246, Time: 2.43 seconds
# Epoch [34/100], Step [190/195], Loss: 0.0148
# Epoch [34/100], Train Loss: 0.0115, Val Loss: 0.0154, Time: 2.44 seconds
# Epoch [35/100], Step [190/195], Loss: 0.0137
# Epoch [35/100], Train Loss: 0.0108, Val Loss: 0.0149, Time: 2.44 seconds
# Epoch [36/100], Step [190/195], Loss: 0.0107
# Epoch [36/100], Train Loss: 0.0108, Val Loss: 0.0136, Time: 2.42 seconds
# Epoch [37/100], Step [190/195], Loss: 0.0117
# Epoch [37/100], Train Loss: 0.0104, Val Loss: 0.0119, Time: 2.42 seconds
# Epoch [38/100], Step [190/195], Loss: 0.0074
# Epoch [38/100], Train Loss: 0.0102, Val Loss: 0.0197, Time: 2.43 seconds
# Epoch [39/100], Step [190/195], Loss: 0.0110
# Epoch [39/100], Train Loss: 0.0105, Val Loss: 0.0134, Time: 2.43 seconds
# Epoch [40/100], Step [190/195], Loss: 0.0134
# Epoch [40/100], Train Loss: 0.0098, Val Loss: 0.0093, Time: 2.43 seconds
# Epoch [41/100], Step [190/195], Loss: 0.0095
# Epoch [41/100], Train Loss: 0.0110, Val Loss: 0.0138, Time: 2.41 seconds
# Early stopping triggered.

# %%
# Final evaluation on the test dataset
model.load_state_dict(best_model)  # Load the best model
# save the best model to the "models" directory
if not os.path.exists('models'):
    os.makedirs('models')
torch.save(best_model, f'models/{model_choice}_best.pth')
model.to(device)
# Out:
# TinyCNN(
#   (model): Sequential(
#     (0): Conv1d(1, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): ReLU()
#     (2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (4): Conv1d(16, 32, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): ReLU()
#     (6): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (8): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (9): ReLU()
#     (10): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): AvgPool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#     (12): AdaptiveAvgPool1d(output_size=1)
#     (13): Flatten(start_dim=1, end_dim=-1)
#     (14): Linear(in_features=64, out_features=64, bias=True)
#     (15): ReLU()
#     (16): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %%
all_predictions, all_true_labels,_,_ = evaluate_model(model, test_loader, loss_function, device)
all_predictions = denormalize(all_predictions, ranges)  # Denormalize predictions
all_true_labels = denormalize(all_true_labels, ranges)  # Denormalize true labels

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)

# Scatter plots for predictions
plt.figure(figsize=(16,7.5))
for j in range(n_labels):
    plt.subplot(1,3,j+1)
    gt = all_true_labels
    plt.scatter(gt[:,j],y=all_predictions[:,j],s=6,alpha=0.2)
    plt.plot([gt[:,j].min().item(),gt[:,j].max().item()],[gt[:,j].min().item(),gt[:,j].max().item()],c="black",linestyle="dashed",label="Perfect prediction")
    plt.xlabel("true "+labelNames[j])
    plt.ylabel("predicted "+labelNames[j])
    plt.legend()
plt.tight_layout()
#plt.savefig('plots/stellarCNN.png')
plt.show()
# Out:
# Evaluating model on the test dataset...
# Final Test Loss: 0.0138
